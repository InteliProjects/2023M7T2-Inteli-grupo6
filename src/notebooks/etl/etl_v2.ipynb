# %% [markdown]
# # Importações necessárias para aplicação

# %%
import pandas as pd
import numpy as np
import os
from scipy import stats

# %% [markdown]
# # Função Principal - TransformedParquet
# * Recebe um arquivo .parquet para tratamento.
# * Realiza o tratamento no nome das colunas, substitue os valores nulos por 0 e remove as linhas duplicadas.
# * Combina colunas com os mesmos significados (Os 2 lados dos motores em um única coluna).
# * Remove outliers.
# * Cria um grupo de tempos 'recording_time'.
# * Segrega cada fase de voos em 30 linhas e realizar uma operação matemática de acordo com as análises de cada coluna.
# * Retorna um arquivo .csv tratado

# %%
def transformParquet(parquet_path):
    df = pd.read_parquet(parquet_path)
    df.columns = df.columns.str.replace('-', '')
    df.fillna(0, inplace=True)
    df.drop_duplicates(inplace=True)
    df['aircraftSerNum1'] = df['aircraftSerNum1']
    df['amscChBasHealthStatus1'] = df['amscChBasHealthStatus1b'] + df['amscChBasHealthStatus1a']
    df['amscChBasHealthStatus2'] = df['amscChBasHealthStatus2b']
    df['amscHprsovDrivF1'] = df['amscHprsovDrivF1b']
    df['amscHprsovDrivF2'] = df['amscHprsovDrivF2b']
    df['amscPrsovDrivF1'] = df['amscPrsovDrivF1a'] + df['amscPrsovDrivF1b']
    df['amscPrsovDrivF2'] = df['amscPrsovDrivF2b']
    df['basBleedLowPressF1'] = df['basBleedLowPressF1a']
    df['basBleedLowPressF2'] = df['basBleedLowPressF2b']
    df['basBleedLowTempF1'] = df['basBleedLowTempF1a']
    df['basBleedLowTempF2'] = df['basBleedLowTempF2b']
    df['basBleedOverPressF1'] = df['basBleedOverPressF1a']
    df['basBleedOverPressF2'] = df['basBleedOverPressF2b']
    df['basBleedOverTempF1'] = df['basBleedOverTempF1a']
    df['basBleedOverTempF2'] = df['basBleedOverTempF2b']
    df['bleedAcsBleedConfigStatus1'] = df['bleedAcsBleedConfigStatus1b']
    df['bleedAcsBleedConfigStatus2'] = df['bleedAcsBleedConfigStatus2b']
    df['bleedFavTmCmd1'] = df['bleedFavTmCmd1a'] + df['bleedFavTmCmd1b']
    df['bleedFavTmCmd2'] = df['bleedFavTmCmd2b'] + df['bleedFavTmCmd2a']
    df['bleedFavTmFbk1'] = df['bleedFavTmFbk1a'] + df['bleedFavTmFbk1b']
    df['bleedFavTmFbk2'] = df['bleedFavTmFbk2b']
    df['bleedHprsovCmdStatus1'] = df['bleedHprsovCmdStatus1b'] + df['bleedHprsovCmdStatus1a']
    df['bleedHprsovCmdStatus2'] = df['bleedHprsovCmdStatus2b'] + df['bleedHprsovCmdStatus2a']
    df['bleedHprsovOpPosStatus1'] = df['bleedHprsovOpPosStatus1b'] + df['bleedHprsovOpPosStatus1a']
    df['bleedHprsovOpPosStatus2'] = df['bleedHprsovOpPosStatus2b'] + df['bleedHprsovOpPosStatus2a']
    df['bleedMonPress1'] = df['bleedMonPress1b'] + df['bleedMonPress1a']
    df['bleedMonPress2'] = df['bleedMonPress2b'] + df['bleedMonPress2a']
    df['bleedOnStatus1'] = df['bleedOnStatus1b'] + df['bleedOnStatus1a']
    df['bleedOnStatus2'] = df['bleedOnStatus2b']
    df['bleedOutTemp1'] = df['bleedOutTemp1b'] + df['bleedOutTemp1a']
    df['bleedOutTemp2'] = df['bleedOutTemp2b'] + df['bleedOutTemp2a']
    df['bleedOutTempTarget1'] = df['bleedOutTempTarget1b'] + df['bleedOutTempTarget1a']
    df['bleedOutTempTarget2'] = df['bleedOutTempTarget2b']
    df['bleedOverpressCas1'] = df['bleedOverpressCas1a']
    df['bleedOverpressCas2'] = df['bleedOverpressCas2b'] + df['bleedOverpressCas2a']
    df['bleedPrecoolDiffPress1'] = df['bleedPrecoolDiffPress1b'] + df['bleedPrecoolDiffPress1a']
    df['bleedPrecoolDiffPress2'] = df['bleedPrecoolDiffPress2b'] + df['bleedPrecoolDiffPress2a']
    df['bleedPrsovClPosStatus1'] = df['bleedPrsovClPosStatus1a']
    df['bleedPrsovClPosStatus2'] = df['bleedPrsovClPosStatus2a']
    df['bleedPrsovFbk1'] = df['bleedPrsovFbk1a'] + df['bleedPrsovFbk1b']
    df['bleedPrsovFbk2'] = df['bleedPrsovFbk2b']
    df['bleedPrsovOpPosStatus1'] = df['bleedPrsovOpPosStatus1a'] + df['bleedPrsovOpPosStatus1b']
    df['bleedPrsovOpPosStatus2'] = df['bleedPrsovOpPosStatus2a'] + df['bleedPrsovOpPosStatus2b']
    df['bleedPrsovTmCmd1'] = df['bleedPrsovTmCmd1a'] + df['bleedPrsovTmCmd1b']
    df['bleedPrsovTmCmd2'] = df['bleedPrsovTmCmd2a'] + df['bleedPrsovTmCmd2b']
    df['bleedSingleOperation1'] = df['bleedSingleOperation1a']
    df['bleedSingleOperation2'] = df['bleedSingleOperation2b']
    df['bleedSwPress1'] = df['bleedSwPress1a'] + df['bleedSwPress1b']
    df['bleedSwPress2'] = df['bleedSwPress2b'] + df['bleedSwPress2a']
    df['correctedCoreSpeed1a'] = df['correctedCoreSpeed1a']
    df['correctedCoreSpeed3a'] = df['correctedCoreSpeed3a']
    df['correctedN1Speed1a'] = df['correctedN1Speed1a']
    df['correctedN1Speed3a'] = df['correctedN1Speed3a']
    df['message0418DAA1'] = df['message0418DAA1']
    df['message0422DAA1'] = df['message0422DAA1']
    df['messageInhibitPhases1'] = df['messageInhibitPhases1']
    df['phaseOfFlight1'] = df['phaseOfFlight1']
    df['phaseOfFlightNavigation1'] = df['phaseOfFlightNavigation1']
    df['sfyBasFaultWord1Bit131'] = df['sfyBasFaultWord1Bit131a']
    df['sfyBasFaultWord1Bit132'] = df['sfyBasFaultWord1Bit132b']
    df['pressAltitude1'] = df['pressAltitude1a']
    df['pressAltitude2'] = df['pressAltitude2a']
    df['pressAltitude3'] = df['pressAltitude3a']
    df['pressAltitude4'] = df['pressAltitude4a']
    df['wOW1'] = df['wOW1a']
    df['wOW3'] = df['wOW3a']
    df.loc[df['message0422DAA1'] != 0, 'message0422DAA1'] = 1
    df.loc[df['message0418DAA1'] != 0, 'message0418DAA1'] = 1

    # Calcule o Z-score para a coluna 'recording_time'
    z_scores = stats.zscore(df['recording_time'])

    # Defina um limite para o Z-score que indica um outlier (por exemplo, 3 desvios padrão)
    limite_z = 3

    # Encontre os índices dos outliers
    indices_outliers = abs(z_scores) > limite_z

    # Remova as linhas que contêm outliers
    df = df[~indices_outliers]
    max_time = df['recording_time'].max()
    bins = np.linspace(0, max_time, 31)
    df['time_group'] = pd.cut(df['recording_time'], bins, labels=range(30), right=False)
    agg_dict = {
        "aircraftSerNum1": "max",
        "amscChBasHealthStatus1": "median",
        "amscChBasHealthStatus2": "median",
        "amscHprsovDrivF1": "median",
        "amscHprsovDrivF2": "median",
        "amscPrsovDrivF1": "median",
        "amscPrsovDrivF2": "median",
        "basBleedLowPressF1": "median",
        "basBleedLowPressF2": "median",
        "basBleedLowTempF1": "max",
        "basBleedLowTempF2": "max",
        "basBleedOverPressF1": "max",
        "basBleedOverPressF2": "max",
        "basBleedOverTempF1": "max",
        "basBleedOverTempF2": "max",
        "bleedAcsBleedConfigStatus1": "max",
        "bleedAcsBleedConfigStatus2": "max",
        "bleedFavTmCmd1": "sum",
        "bleedFavTmCmd2": "sum",
        "bleedFavTmFbk1": "sum",
        "bleedFavTmFbk2": "sum",
        "bleedHprsovCmdStatus1": "max",
        "bleedHprsovCmdStatus2": "max",
        "bleedHprsovOpPosStatus1": "max",
        "bleedHprsovOpPosStatus2": "max",
        "bleedMonPress1": "median",
        "bleedMonPress2": "median",
        "bleedOnStatus1": "median",
        "bleedOnStatus2": "median",
        "bleedOutTemp1": "max",
        "bleedOutTemp2": "max",
        "bleedOutTempTarget1": "sum",
        "bleedOutTempTarget2": "sum",
        "bleedOverpressCas1": "max",
        "bleedOverpressCas2": "max",
        "bleedPrecoolDiffPress1": "median",
        "bleedPrecoolDiffPress2": "median",
        "bleedPrsovClPosStatus1": "max",
        "bleedPrsovClPosStatus2": "max",
        "bleedPrsovFbk1": "median",
        "bleedPrsovFbk2": "median",
        "bleedPrsovOpPosStatus1": "max",
        "bleedPrsovOpPosStatus2": "max",
        "bleedPrsovTmCmd1": "median",
        "bleedPrsovTmCmd2": "median",
        "bleedSingleOperation1": "max",
        "bleedSingleOperation2": "max",
        "bleedSwPress1": "median",
        "bleedSwPress2": "median",
        "correctedCoreSpeed1a": "median",
        "correctedCoreSpeed3a": "median",
        "correctedN1Speed1a": "median",
        "correctedN1Speed3a": "median",
        "message0418DAA1": "max",
        "message0422DAA1": "max",
        "messageInhibitPhases1": "max",
        "phaseOfFlight1": "median",
        "phaseOfFlightNavigation1": "max",
        "sfyBasFaultWord1Bit131": "mean",
        "sfyBasFaultWord1Bit132": "mean",
        "pressAltitude1": "median",
        "pressAltitude2": "median",
        "pressAltitude3": "median",
        "pressAltitude4": "median",
        "wOW1": "max",
        "wOW3": "max",
    }
    df_agrupado_fases_voo = df.groupby('time_group').agg(agg_dict).reset_index(drop=True)
    return df_agrupado_fases_voo

# %% [markdown]
# ### Esse código é reponsável por entrar no diretório, ver todos os arquivos que existem e retornar uma array com toda a lista de arquivos.

# %%
pasta = './parquets'
arquivos_na_pasta = os.listdir(pasta)

# %% [markdown]
# ### Lógica que mediante a lista de todos os nomes dos aquivos coletados anteriormente, o 'for' vai entrar em cada um deles e realizar o tratamento pela função 'def transformed_parquet'. Após o tratamento, os arquivos seram salvos e concatenados em uma variável que por ultimo é gerado um arquivo .cvs com os dados tratados.

# %%
dados_agregados = pd.DataFrame()

# %%
for arquivo in arquivos_na_pasta:
    caminho = pasta + '/' + arquivo
    print("Transformando o arquivo: " + caminho)
    transformed_parquet = transformParquet(caminho)
    dados_agregados = pd.concat([dados_agregados, transformed_parquet], ignore_index=True)
# Out:
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221007005544.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221031141941.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230718235244.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230414180132.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230801103202.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230622152932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221112234342.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220920051002.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230813102010.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221219082344.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230506215344.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230330101142.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230505020531.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230124102313.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230606210233.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230419044039.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20220507043902.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230806123635.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230814172831.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221117224840.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230726014432.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230228223540.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20220805050741.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230124102303.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230523121230.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230719042234.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221215222642.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230402173934.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230710173031.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230608150430.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221115225741.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230506231731.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230306094607.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230728012834.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221023214507.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230727041841.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230726075435.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230809003931.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230718014041.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230817095404.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230817081634.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230204150441.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230822125409.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221119045741.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230806101835.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221201125538.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220914212039.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230615113601.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220718233339.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220917122240.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220920143638.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230803130545.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220530132601.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230507151743.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221001140201.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230415032131.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221229174642.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230302123502.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230313095108.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220720234502.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221006161041.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230710194801.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230729174942.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230820231438.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230818172932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230325203335.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220914102006.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230508223645.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220722174238.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120020_20230802024201.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220608103140.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230704205439.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230503013634.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230501081033.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230806203401.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220829045108.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230527033531.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230116152842.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230709125644.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230802081433.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230320035843.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230506013743.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230430082245.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230730210731.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230627140839.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220907050639.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230428114901.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230624123444.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221101100441.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230717113301.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220826154141.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230609002102.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230809151531.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230805231335.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220909234643.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230424102602.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220716232740.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221206203540.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230416151432.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120020_20230802024211.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230724041032.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230724183436.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20220708224542.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221031191340.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230124043131.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230331015931.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230106004643.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230817050535.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20221205224944.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230702225732.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221027103302.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230625083235.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230822042935.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120035_20230815124101.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230508102040.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20221217200030.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20220824113701.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230808205545.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230130032133.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220811050541.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221207102906.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230702144540.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221128235640.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230705230502.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230123014934.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230425193531.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230228043131.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120018_20230326224140.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120035_20230815124111.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230725173333.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230218181633.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230621172133.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221118195841.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20220507192402.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221224231241.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230620153132.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230208233631.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20221031183004.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120018_20230723013637.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230519023644.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220925213946.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230616201433.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20220701184444.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230106030441.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230531230135.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220915081242.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230812044242.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220927174640.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221022194437.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220829044302.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230513021232.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230628104006.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230715230732.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20221222035238.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230802040033.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230723161131.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230120220234.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230125150333.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230307094403.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230809230444.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221213172440.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220831225542.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230501195631.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230706122208.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230301151035.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230208120931.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230803231932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230317150533.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230307125040.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221220121939.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220529044841.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230719125301.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230717102540.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230816131101.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221213011839.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230526115930.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230711105035.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230503020209.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230612035732.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221107193241.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20220709193742.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230807154203.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220628233539.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230802214944.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230121104237.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230731214446.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230210234433.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230330153133.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221215101241.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230128144742.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230127005730.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230622124931.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120018_20230817014938.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230202184732.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221115100906.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221108021842.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230601082033.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230613024130.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221124051342.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221121083343.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230811180401.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230701191632.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221215130803.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230731120804.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230619233638.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230327152830.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20221205133802.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230309200642.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230222223233.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220606130601.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221124133204.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221211200742.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220809100606.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230604123731.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230814094611.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120035_20230729001003.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230808082447.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230128052745.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230109230830.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120035_20230801032135.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230811214535.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230402140141.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230422040831.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230717031530.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230103095544.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20221028132537.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230412000743.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220726194210.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230814094601.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120035_20230729001013.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230731190531.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230413174431.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230303215429.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230507103106.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230118210531.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230123073245.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230524123230.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220815132338.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230723180744.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230803153302.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230815132302.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230207010732.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230720010930.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221002080043.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230805141634.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221006103209.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230629050333.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230810140443.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230219181232.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230117194239.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230312193832.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20220929195340.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20220917145740.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221224034511.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230726171431.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220907001340.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230201175003.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230419130432.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230124231630.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230817225234.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230128224343.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120035_20230822131437.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230127200839.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230105125631.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230303100831.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220719120238.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220816182143.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230312042602.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221010235002.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221102183240.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221224034501.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230710170132.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230822124046.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230102204842.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230804220441.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230619131133.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230617194737.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221013132438.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230525102903.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230314190601.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230614132131.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230701145031.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221021101540.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230809180245.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230816200148.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230814172734.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230602150032.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230421172541.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220605122309.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220811225240.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230721004131.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220816102414.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221018150440.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230210205534.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230205100732.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230106103705.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230331042101.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230729212631.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230722100930.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230728230033.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230420005431.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230324213234.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230819004733.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220816102404.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230507155638.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220821154741.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230422144244.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230127143341.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230222161530.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230807194831.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230327111305.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230304132403.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230812154533.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230303104402.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230227172631.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230203020205.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230730175746.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230418155033.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230822125401.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230216215302.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230604154133.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120020_20220329082441.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230626231930.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220927124739.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120020_20201209125922.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230208184131.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230113074043.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230822102901.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230104185542.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230331111205.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230513225634.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220630050903.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230723230942.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120018_20230728003239.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230430123601.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230730200533.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230810163731.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230714182144.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220607224342.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230115183430.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230412124301.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230216002630.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220610193736.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230326103901.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230722125304.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230818131632.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220630050913.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220625153401.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230410224203.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230714030131.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230617102203.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230219215932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230331111215.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230621020030.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230118154031.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230418041337.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230525103531.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230401043043.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220917221145.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120018_20230725102337.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230330173431.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230203222742.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230401235945.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230425105737.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20221222152942.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230204132703.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230621150332.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230413124201.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220705193004.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230816120401.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220712215601.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221206004241.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120035_20230804105801.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230210142302.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230215083042.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230611040334.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20221214195232.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230710100932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230512235443.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230323221630.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230720102835.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221219101040.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230217222531.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230822154846.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230410054934.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230729033530.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220701203843.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120035_20230822080138.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230623235432.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221015222542.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220728104202.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230819190735.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230309102532.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230308044144.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220604014040.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230707011932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230630130039.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230629094431.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230806173302.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230805193232.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230719224042.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230315150631.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230520101732.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230803110532.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221107152341.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230329033130.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220614051542.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230726231734.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230324132408.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220704202644.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20211226002641.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221102015143.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230529015446.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230214122303.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230516023131.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230512020431.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221204103152.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230221132130.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230315233030.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230423122743.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230608211642.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230313225231.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220810102501.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230407035439.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230708234531.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230722164447.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230719125431.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230321025533.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230616053246.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220616145337.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221028081045.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230422123002.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20221108224538.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221203041806.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220818050443.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220613214240.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230131104732.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230309100230.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230501225334.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230531234402.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230509234836.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230812015501.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120020_20201119131837.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230129124643.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221228094046.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230512143534.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230614045932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221021174840.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230712080537.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230630021401.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230514043441.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230716151439.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230814011831.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221125001141.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230423042631.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230518102202.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230814000535.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230306222631.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230529130541.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220729215143.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230218010332.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20220524164439.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230729111901.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230226042601.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220623224304.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230424025640.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230516122405.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230206052032.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220813215202.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20221111102605.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230721151631.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230520180732.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221227035045.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221115194540.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220726151139.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230424234833.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230413135331.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230317105640.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20221217050932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230104225139.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230724095132.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230112151503.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221226000139.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221005224843.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221101220602.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220831155241.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120083_20230819191831.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230215102804.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230719180432.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230107102101.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221029023041.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230808075805.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120020_20230803155239.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230803111630.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230718101932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230710144131.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230206183743.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230131125631.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221102011441.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230411233801.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230215102814.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221218152403.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230319131004.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230329002842.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230731080240.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220604233642.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20221118110339.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230728103202.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120020_20230803100907.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221126102441.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220711100541.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230527133402.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230708194944.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230329224902.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230226000114.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230401081743.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230427140938.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230619041130.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230212205433.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230728172801.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230524050231.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230622173732.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230803011347.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221212155639.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230624175031.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230822181134.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230814201545.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230529100631.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230615152932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120018_20230508025639.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20221227183742.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230618233433.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221207152239.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230427175131.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230108194041.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230226000104.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230801033438.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220807151340.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230424235238.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230405012532.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221103210239.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230401124343.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230102023932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230623095203.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221003102309.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230612125544.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230812024832.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230224175731.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221120185542.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230812102332.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221213124540.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221015182139.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120035_20230812130635.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230727082933.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230531095908.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220825220341.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221129142542.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230209051033.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221205212503.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230307235843.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230123202942.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20221127231840.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230508105732.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230624221932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230729104930.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220614044310.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230203191730.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221222133341.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230531095918.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230213233239.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230703222332.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230418001233.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230411001831.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220711204443.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221116194439.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230813200334.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230628084432.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230508230330.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230225013140.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230811152641.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230714050245.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221021003941.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220824124741.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230622095534.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220527012041.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230713043802.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230630171142.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230421172232.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230719011332.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220906183539.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221012234739.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230812025733.parquet
# ...
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230331181531.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230327172331.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230308143142.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221028115439.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230820140109.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230104011532.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230508081844.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220630050906.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230629021230.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230313101932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230204192645.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20201211045515.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20230822102904.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230118033932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230520194343.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221115193940.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230705040033.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220721154939.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230615172744.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230411050532.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230505102532.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230628233034.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221030081642.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230523203334.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221031151339.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120035_20230804105804.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230804100830.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20220312044809.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230507211034.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230722213745.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230814215940.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230330045932.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230812191441.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230628150833.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230818100632.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230313140340.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230417010734.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20221114224505.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230128202342.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230512201041.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230703022235.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221210023942.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230425102431.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230621124901.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230113080141.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230821051833.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20221227101507.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230724131533.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230319182530.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230123025132.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230509193933.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230603150230.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20201015100321.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230227181731.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230407131530.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230219035802.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220913202042.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230423081444.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230412233331.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120018_20230813154101.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220705193001.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230209044133.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230616001133.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230610141232.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221225171738.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220729233540.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230510183731.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230513014630.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230209143131.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230622043734.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230402190241.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230804152632.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230512160330.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230522183341.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230219200242.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230818222132.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230419123535.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230204135304.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230223012931.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230524024534.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120018_20230730224939.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230521181831.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230223175832.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120021_20220214172845.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220614044305.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230613092841.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220610160941.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221016101740.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230814124837.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221226140040.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120083_20230728130632.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230816083134.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221019180202.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230129182142.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221023101902.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230403201941.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220731231139.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230528102702.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230422100608.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230419205341.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230312123830.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221120101901.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220728213838.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230407111802.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230716122207.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220707001139.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230724132001.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230725174908.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230426163632.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120035_20230815192335.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230625150634.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221113102103.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230809220934.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230413111802.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230118103741.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220718013537.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230419045601.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230708165035.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230626214432.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230603032441.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221014102602.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230411101130.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20221112232741.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230816075635.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230201130931.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221109012040.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20220525212041.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230729231532.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120020_20220413103705.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220906031205.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230702150030.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230219075931.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230806135142.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230412173930.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230619192531.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220718050402.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230818050947.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230802092735.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221223015340.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230617102831.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230218230901.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120020_20230803100902.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230812045432.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230507021731.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230319131001.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230411233804.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230215102811.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230531002431.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220715183503.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221129045544.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230117143431.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120092_20230621172032.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230128100730.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230716080934.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220613101741.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221217035639.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220831100802.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230215102801.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220719051139.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230809173530.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120025_20230224235944.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230418144937.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230120152905.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230606214330.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230112151506.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230417153431.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230119214033.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221011024741.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120077_20230319180532.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230319131431.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230405102601.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120088_20230307223531.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120081_20230311175630.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230226000101.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220921222437.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221031225444.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120091_20230724153533.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230508160038.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220729101845.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20220704232039.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230516172140.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20230226000111.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20230106225344.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120032_20220714040740.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230722004433.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120083_20230727170731.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20230107214142.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220605133003.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230405100430.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20221109005942.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120028_20230502151636.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120089_20230705234132.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221006142540.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230729030532.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120079_20230202205733.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120033_20221028154542.parquet
# Transformando o arquivo: ./parquets/TCRF_ARCHIVE_06120034_20220830144243.parquet

# %%
dados_agregados.to_csv('dados_agregados.csv', index=False)
